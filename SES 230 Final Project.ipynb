# %% [markdown]
# Simulation of a baseball game:

# %%
import random

class Player:
    def __init__(self, name, batting_average, strikeout_probability, out_field_probability):
        self.name = name
        self.batting_average = batting_average
        self.strikeout_probability = strikeout_probability
        self.out_field_probability = out_field_probability

    def get_hit(self, pitcher_strike_probability):
        """Determine if the player gets a hit based on their batting average and the pitcher's skill."""
        random_number = random.random()
        if random_number < self.batting_average * (1 - pitcher_strike_probability):
            # Player gets a hit
            return True
        elif random_number < (self.batting_average + self.strikeout_probability) * (1 - pitcher_strike_probability):
            # Player strikes out
            return False
        elif random_number < (self.batting_average + self.strikeout_probability + self.out_field_probability) * (1 - pitcher_strike_probability):
            # Player gets out from the field
            return False
        else:
            # Player doesn't get a hit, strike out, or out from the field/base
            return None

class Pitcher:
    def __init__(self, name, strike_probability):
        self.name = name
        self.strike_probability = strike_probability

    def throw_pitch(self):
        """Determine if the pitcher throws a ball or a strike."""
        return random.random() < self.strike_probability

class Team:
    def __init__(self, name, players, pitcher):
      self.name = name
      self.players = players
      self.pitcher = pitcher
      self.current_batter_index = 0

    def simulate_inning(self):
        score = 0
        outs = 0
        on_base = 0

        while outs < 3:
            player = self.players[self.current_batter_index]
            strikes = 0
            balls = 0

            print(f"\n{player.name}'s at-bat:")
            while strikes < 3 and balls < 4:
                if self.pitcher.throw_pitch():
                    result = player.get_hit(self.pitcher.strike_probability)
                    if result is not None:
                        if result:
                            on_base += 1
                            if on_base >= 4:
                                score += 1
                                on_base -= 1
                            print(f"{player.name} of {self.name} got a hit! Players on base: {on_base}")
                            break  # Break the at-bat loop after getting a hit
                        else:
                            if random.random() < player.out_field_probability:
                                print(f"{player.name} of {self.name} got out in the field!")
                                outs += 1
                                break
                            else:
                                strikes += 1  # Increment the strike counter
                                print(f"{player.name} of {self.name} received a strike! Strikes: {strikes}")
                                if strikes == 3:
                                    print(f"{player.name} of {self.name} struck out!")
                                    outs += 1
                                    break
                    else:
                        balls += 1
                        print(f"{player.name} of {self.name} got a ball! Balls: {balls}")

                # Check if the player got a free base after getting a hit
                if on_base >= 4:
                    on_base -= 1
                    print(f"{player.name} of {self.name} got a free base! Players on base: {on_base}")

            self.current_batter_index = (self.current_batter_index + 1) % len(self.players)

        return score, outs, on_base


def simulate_game(Texas_Rangers, Arizona_Diamondbacks):
    Texas_Rangers_total_score = 0
    Arizona_Diamondbacks_total_score = 0
    inning = 1

    while inning <= 9 or Texas_Rangers_total_score == Arizona_Diamondbacks_total_score:
        print(f"\nInning {inning}:")
        Texas_Rangers_score, Texas_Rangers_outs, Texas_Rangers_on_base = Texas_Rangers.simulate_inning()
        Arizona_Diamondbacks_score, Arizona_Diamondbacks_outs, Arizona_Diamondbacks_on_base = Arizona_Diamondbacks.simulate_inning()
        print(f"Runs scored in inning {inning}: {Texas_Rangers.name} - {Texas_Rangers_score}, {Arizona_Diamondbacks.name} - {Arizona_Diamondbacks_score}")
        print(f"Outs after inning {inning}: {Texas_Rangers.name} - {Texas_Rangers_outs}, {Arizona_Diamondbacks.name} - {Arizona_Diamondbacks_outs}")
        print(f"On base after inning {inning}: {Texas_Rangers.name} - {Texas_Rangers_on_base}, {Arizona_Diamondbacks.name} - {Arizona_Diamondbacks_on_base}")

        Texas_Rangers_total_score += Texas_Rangers_score
        Arizona_Diamondbacks_total_score += Arizona_Diamondbacks_score

        inning += 1

        if inning > 9 and Texas_Rangers_total_score == Arizona_Diamondbacks_total_score:
            print("Extra inning!")

    print(f"\nFinal Score: {Texas_Rangers.name} - {Texas_Rangers_total_score}, {Arizona_Diamondbacks.name} - {Arizona_Diamondbacks_total_score}")

    if Texas_Rangers_total_score > Arizona_Diamondbacks_total_score:
        print(f"{Texas_Rangers.name} wins!")
    elif Arizona_Diamondbacks_total_score > Texas_Rangers_total_score:
        print(f"{Arizona_Diamondbacks.name} wins!")
    else:
        print("The game is a tie after extra innings!")


# Create players for each team with unique batting averages
Texas_Rangers_players = [
    
    Player("Jonah Heim", 0.258, 0.21, 0.532),
    Player("Nathaniel Lowe", 0.262, 0.263, 0.475),
    Player("Marcus Semien", 0.276, 0.164, 0.56),
    Player("Corey Seager", 0.327, 0.184, 0.489),
    Player("Josh Jung", 0.266, 0.316, 0.418),
    Player("Evan Carter", 0.263, 0.38, 0.354),
    Player("Leody Taveras", 0.266, 0.229, 0.435 ),
    Player("Adolis García", 0.245, 0.315, 0.44 ),
    Player("Mitch Garver", 0.270, 0.277,0.453)
]

Arizona_Diamondbacks_players = [
    
    Player("Corbin Carrol", 0.258, 0.220, 0.522),
    Player("Ketel Marte", 0.276, 0.190, 0.534),
    Player("Gabriel Moreno", 0.284, 0.219, 0.497),
    Player("Christian Walker", 0.258, 0.218, 0.524),
    Player("Tommy Pham", 0.241, 0.256, 0.503),
    Player("Lourdes Gurriel Jr.", 0.261, 0.187,0.552),
    Player("Alek Thomas", 0.230, 0.223, 0.547),
    Player("Evan Longoria", 0.223, 0.346, 0.431),
    Player("Geraldo Perdomo", 0.246, 0.211,0.543)
]

# Create pitchers for each team with unique skills
Texas_Rangers_pitcher = Pitcher("Dane Dunning", 0.562)  # Pitcher from the Texas Rangers
Arizona_Diamondbacks_pitcher = Pitcher("Zac Gallen", 0.50)  # Pitcher from the Arizona Diamondbacks

# Create teams
Texas_Rangers = Team("Texas Rangers", Texas_Rangers_players, Texas_Rangers_pitcher)
Arizona_Diamondbacks = Team("Arizona Diamondbacks", Arizona_Diamondbacks_players, Arizona_Diamondbacks_pitcher)

# Run the simulation
simulate_game(Texas_Rangers, Arizona_Diamondbacks)
# Out:
# Inning 1:
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got a ball! Balls: 1
# Jonah Heim of Texas Rangers got a hit! Players on base: 1
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 1
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 2
# Nathaniel Lowe of Texas Rangers got a hit! Players on base: 2
#
# Marcus Semien's at-bat:
# Marcus Semien of Texas Rangers got a ball! Balls: 1
# Marcus Semien of Texas Rangers got out in the field!
#
# Corey Seager's at-bat:
# Corey Seager of Texas Rangers got a ball! Balls: 1
# Corey Seager of Texas Rangers got a ball! Balls: 2
# Corey Seager of Texas Rangers got out in the field!
#
# Josh Jung's at-bat:
# Josh Jung of Texas Rangers received a strike! Strikes: 1
# Josh Jung of Texas Rangers got a hit! Players on base: 3
#
# Evan Carter's at-bat:
# Evan Carter of Texas Rangers got out in the field!
#
# Corbin Carrol's at-bat:
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 1
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 2
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 3
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 4
#
# Ketel Marte's at-bat:
# Ketel Marte of Arizona Diamondbacks got a hit! Players on base: 1
#
# Gabriel Moreno's at-bat:
# Gabriel Moreno of Arizona Diamondbacks got a ball! Balls: 1
# Gabriel Moreno of Arizona Diamondbacks got a hit! Players on base: 2
#
# Christian Walker's at-bat:
# Christian Walker of Arizona Diamondbacks received a strike! Strikes: 1
# Christian Walker of Arizona Diamondbacks got a hit! Players on base: 3
#
# Tommy Pham's at-bat:
# Tommy Pham of Arizona Diamondbacks received a strike! Strikes: 1
# Tommy Pham of Arizona Diamondbacks received a strike! Strikes: 2
# Tommy Pham of Arizona Diamondbacks got out in the field!
#
# Lourdes Gurriel Jr.'s at-bat:
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a hit! Players on base: 3
#
# Alek Thomas's at-bat:
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 1
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 2
# Alek Thomas of Arizona Diamondbacks received a strike! Strikes: 1
# Alek Thomas of Arizona Diamondbacks received a strike! Strikes: 2
# Alek Thomas of Arizona Diamondbacks got out in the field!
#
# Evan Longoria's at-bat:
# Evan Longoria of Arizona Diamondbacks received a strike! Strikes: 1
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 1
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 2
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 3
# Evan Longoria of Arizona Diamondbacks got out in the field!
# Runs scored in inning 1: Texas Rangers - 0, Arizona Diamondbacks - 1
# Outs after inning 1: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 1: Texas Rangers - 3, Arizona Diamondbacks - 3
#
# Inning 2:
#
# Leody Taveras's at-bat:
# Leody Taveras of Texas Rangers got a ball! Balls: 1
# Leody Taveras of Texas Rangers got a ball! Balls: 2
# Leody Taveras of Texas Rangers got a ball! Balls: 3
# Leody Taveras of Texas Rangers got a ball! Balls: 4
#
# Adolis García's at-bat:
# Adolis García of Texas Rangers got a ball! Balls: 1
# Adolis García of Texas Rangers got a ball! Balls: 2
# Adolis García of Texas Rangers got out in the field!
#
# Mitch Garver's at-bat:
# Mitch Garver of Texas Rangers got a ball! Balls: 1
# Mitch Garver of Texas Rangers got out in the field!
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got a hit! Players on base: 1
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers got a hit! Players on base: 2
#
# Marcus Semien's at-bat:
# Marcus Semien of Texas Rangers got out in the field!
#
# Geraldo Perdomo's at-bat:
# Geraldo Perdomo of Arizona Diamondbacks received a strike! Strikes: 1
# Geraldo Perdomo of Arizona Diamondbacks received a strike! Strikes: 2
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 1
# Geraldo Perdomo of Arizona Diamondbacks got a hit! Players on base: 1
#
# Corbin Carrol's at-bat:
# Corbin Carrol of Arizona Diamondbacks received a strike! Strikes: 1
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 1
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 2
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 3
# Corbin Carrol of Arizona Diamondbacks got out in the field!
#
# Ketel Marte's at-bat:
# Ketel Marte of Arizona Diamondbacks received a strike! Strikes: 1
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 1
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 2
# Ketel Marte of Arizona Diamondbacks got out in the field!
#
# Gabriel Moreno's at-bat:
# Gabriel Moreno of Arizona Diamondbacks received a strike! Strikes: 1
# Gabriel Moreno of Arizona Diamondbacks got a ball! Balls: 1
# Gabriel Moreno of Arizona Diamondbacks got a ball! Balls: 2
# Gabriel Moreno of Arizona Diamondbacks got a hit! Players on base: 2
#
# Christian Walker's at-bat:
# Christian Walker of Arizona Diamondbacks got a ball! Balls: 1
# Christian Walker of Arizona Diamondbacks got a ball! Balls: 2
# Christian Walker of Arizona Diamondbacks got a ball! Balls: 3
# Christian Walker of Arizona Diamondbacks got a ball! Balls: 4
#
# Tommy Pham's at-bat:
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 1
# Tommy Pham of Arizona Diamondbacks got a hit! Players on base: 3
#
# Lourdes Gurriel Jr.'s at-bat:
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a hit! Players on base: 3
#
# Alek Thomas's at-bat:
# Alek Thomas of Arizona Diamondbacks got out in the field!
# Runs scored in inning 2: Texas Rangers - 0, Arizona Diamondbacks - 1
# Outs after inning 2: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 2: Texas Rangers - 2, Arizona Diamondbacks - 3
#
# Inning 3:
#
# Corey Seager's at-bat:
# Corey Seager of Texas Rangers got a ball! Balls: 1
# Corey Seager of Texas Rangers got a hit! Players on base: 1
#
# Josh Jung's at-bat:
# Josh Jung of Texas Rangers got a ball! Balls: 1
# Josh Jung of Texas Rangers got a ball! Balls: 2
# Josh Jung of Texas Rangers got a ball! Balls: 3
# Josh Jung of Texas Rangers got a hit! Players on base: 2
#
# Evan Carter's at-bat:
# Evan Carter of Texas Rangers got a hit! Players on base: 3
#
# Leody Taveras's at-bat:
# Leody Taveras of Texas Rangers received a strike! Strikes: 1
# Leody Taveras of Texas Rangers got a ball! Balls: 1
# Leody Taveras of Texas Rangers got a ball! Balls: 2
# Leody Taveras of Texas Rangers received a strike! Strikes: 2
# Leody Taveras of Texas Rangers got a hit! Players on base: 3
#
# Adolis García's at-bat:
# Adolis García of Texas Rangers got out in the field!
#
# Mitch Garver's at-bat:
# Mitch Garver of Texas Rangers got out in the field!
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got a hit! Players on base: 3
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers received a strike! Strikes: 1
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 1
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 2
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 3
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 4
#
# Marcus Semien's at-bat:
# Marcus Semien of Texas Rangers got a ball! Balls: 1
# Marcus Semien of Texas Rangers got a ball! Balls: 2
# Marcus Semien of Texas Rangers got a ball! Balls: 3
# Marcus Semien of Texas Rangers received a strike! Strikes: 1
# Marcus Semien of Texas Rangers received a strike! Strikes: 2
# Marcus Semien of Texas Rangers received a strike! Strikes: 3
# Marcus Semien of Texas Rangers struck out!
#
# Evan Longoria's at-bat:
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 1
# Evan Longoria of Arizona Diamondbacks got out in the field!
#
# Geraldo Perdomo's at-bat:
# Geraldo Perdomo of Arizona Diamondbacks got a hit! Players on base: 1
#
# Corbin Carrol's at-bat:
# Corbin Carrol of Arizona Diamondbacks got out in the field!
#
# Ketel Marte's at-bat:
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 1
# Ketel Marte of Arizona Diamondbacks received a strike! Strikes: 1
# Ketel Marte of Arizona Diamondbacks got out in the field!
# Runs scored in inning 3: Texas Rangers - 2, Arizona Diamondbacks - 0
# Outs after inning 3: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 3: Texas Rangers - 3, Arizona Diamondbacks - 1
#
# Inning 4:
#
# Corey Seager's at-bat:
# Corey Seager of Texas Rangers got a ball! Balls: 1
# Corey Seager of Texas Rangers got a ball! Balls: 2
# Corey Seager of Texas Rangers got out in the field!
#
# Josh Jung's at-bat:
# Josh Jung of Texas Rangers got a ball! Balls: 1
# Josh Jung of Texas Rangers got a ball! Balls: 2
# Josh Jung of Texas Rangers got a ball! Balls: 3
# Josh Jung of Texas Rangers received a strike! Strikes: 1
# Josh Jung of Texas Rangers got out in the field!
#
# Evan Carter's at-bat:
# Evan Carter of Texas Rangers got a ball! Balls: 1
# Evan Carter of Texas Rangers got a ball! Balls: 2
# Evan Carter of Texas Rangers received a strike! Strikes: 1
# Evan Carter of Texas Rangers received a strike! Strikes: 2
# Evan Carter of Texas Rangers got a hit! Players on base: 1
#
# Leody Taveras's at-bat:
# Leody Taveras of Texas Rangers got a hit! Players on base: 2
#
# Adolis García's at-bat:
# Adolis García of Texas Rangers received a strike! Strikes: 1
# Adolis García of Texas Rangers got a ball! Balls: 1
# Adolis García of Texas Rangers got a ball! Balls: 2
# Adolis García of Texas Rangers got out in the field!
#
# Gabriel Moreno's at-bat:
# Gabriel Moreno of Arizona Diamondbacks got a ball! Balls: 1
# Gabriel Moreno of Arizona Diamondbacks got out in the field!
#
# Christian Walker's at-bat:
# Christian Walker of Arizona Diamondbacks got a hit! Players on base: 1
#
# Tommy Pham's at-bat:
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 1
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 2
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 3
# Tommy Pham of Arizona Diamondbacks got a hit! Players on base: 2
#
# Lourdes Gurriel Jr.'s at-bat:
# Lourdes Gurriel Jr. of Arizona Diamondbacks received a strike! Strikes: 1
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 1
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 2
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a hit! Players on base: 3
#
# Alek Thomas's at-bat:
# Alek Thomas of Arizona Diamondbacks received a strike! Strikes: 1
# Alek Thomas of Arizona Diamondbacks got a hit! Players on base: 3
#
# Evan Longoria's at-bat:
# Evan Longoria of Arizona Diamondbacks received a strike! Strikes: 1
# Evan Longoria of Arizona Diamondbacks received a strike! Strikes: 2
# Evan Longoria of Arizona Diamondbacks got out in the field!
#
# Geraldo Perdomo's at-bat:
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 1
# Geraldo Perdomo of Arizona Diamondbacks received a strike! Strikes: 1
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 2
# Geraldo Perdomo of Arizona Diamondbacks got a hit! Players on base: 3
#
# Corbin Carrol's at-bat:
# Corbin Carrol of Arizona Diamondbacks got a hit! Players on base: 3
#
# Ketel Marte's at-bat:
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 1
# Ketel Marte of Arizona Diamondbacks got out in the field!
# Runs scored in inning 4: Texas Rangers - 0, Arizona Diamondbacks - 3
# Outs after inning 4: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 4: Texas Rangers - 2, Arizona Diamondbacks - 3
#
# Inning 5:
#
# Mitch Garver's at-bat:
# Mitch Garver of Texas Rangers got a hit! Players on base: 1
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got a ball! Balls: 1
# Jonah Heim of Texas Rangers got out in the field!
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 1
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 2
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 3
# Nathaniel Lowe of Texas Rangers received a strike! Strikes: 1
# Nathaniel Lowe of Texas Rangers got a hit! Players on base: 2
#
# Marcus Semien's at-bat:
# Marcus Semien of Texas Rangers got out in the field!
#
# Corey Seager's at-bat:
# Corey Seager of Texas Rangers got a ball! Balls: 1
# Corey Seager of Texas Rangers got a ball! Balls: 2
# Corey Seager of Texas Rangers got a hit! Players on base: 3
#
# Josh Jung's at-bat:
# Josh Jung of Texas Rangers got a ball! Balls: 1
# Josh Jung of Texas Rangers got a ball! Balls: 2
# Josh Jung of Texas Rangers got a ball! Balls: 3
# Josh Jung of Texas Rangers received a strike! Strikes: 1
# Josh Jung of Texas Rangers received a strike! Strikes: 2
# Josh Jung of Texas Rangers got a ball! Balls: 4
#
# Evan Carter's at-bat:
# Evan Carter of Texas Rangers got out in the field!
#
# Gabriel Moreno's at-bat:
# Gabriel Moreno of Arizona Diamondbacks got a hit! Players on base: 1
#
# Christian Walker's at-bat:
# Christian Walker of Arizona Diamondbacks got a hit! Players on base: 2
#
# Tommy Pham's at-bat:
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 1
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 2
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 3
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 4
#
# Lourdes Gurriel Jr.'s at-bat:
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 1
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 2
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 3
# Lourdes Gurriel Jr. of Arizona Diamondbacks got out in the field!
#
# Alek Thomas's at-bat:
# Alek Thomas of Arizona Diamondbacks received a strike! Strikes: 1
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 1
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 2
# Alek Thomas of Arizona Diamondbacks received a strike! Strikes: 2
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 3
# Alek Thomas of Arizona Diamondbacks got out in the field!
#
# Evan Longoria's at-bat:
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 1
# Evan Longoria of Arizona Diamondbacks got out in the field!
# Runs scored in inning 5: Texas Rangers - 0, Arizona Diamondbacks - 0
# Outs after inning 5: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 5: Texas Rangers - 3, Arizona Diamondbacks - 2
#
# Inning 6:
#
# Leody Taveras's at-bat:
# Leody Taveras of Texas Rangers received a strike! Strikes: 1
# Leody Taveras of Texas Rangers got a hit! Players on base: 1
#
# Adolis García's at-bat:
# Adolis García of Texas Rangers received a strike! Strikes: 1
# Adolis García of Texas Rangers got a ball! Balls: 1
# Adolis García of Texas Rangers got a ball! Balls: 2
# Adolis García of Texas Rangers received a strike! Strikes: 2
# Adolis García of Texas Rangers got a ball! Balls: 3
# Adolis García of Texas Rangers got a ball! Balls: 4
#
# Mitch Garver's at-bat:
# Mitch Garver of Texas Rangers got out in the field!
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got a ball! Balls: 1
# Jonah Heim of Texas Rangers got a ball! Balls: 2
# Jonah Heim of Texas Rangers got a ball! Balls: 3
# Jonah Heim of Texas Rangers got out in the field!
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers got out in the field!
#
# Geraldo Perdomo's at-bat:
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 1
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 2
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 3
# Geraldo Perdomo of Arizona Diamondbacks got out in the field!
#
# Corbin Carrol's at-bat:
# Corbin Carrol of Arizona Diamondbacks got a ball! Balls: 1
# Corbin Carrol of Arizona Diamondbacks received a strike! Strikes: 1
# Corbin Carrol of Arizona Diamondbacks received a strike! Strikes: 2
# Corbin Carrol of Arizona Diamondbacks received a strike! Strikes: 3
# Corbin Carrol of Arizona Diamondbacks struck out!
#
# Ketel Marte's at-bat:
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 1
# Ketel Marte of Arizona Diamondbacks received a strike! Strikes: 1
# Ketel Marte of Arizona Diamondbacks received a strike! Strikes: 2
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 2
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 3
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 4
#
# Gabriel Moreno's at-bat:
# Gabriel Moreno of Arizona Diamondbacks got a hit! Players on base: 1
#
# Christian Walker's at-bat:
# Christian Walker of Arizona Diamondbacks received a strike! Strikes: 1
# Christian Walker of Arizona Diamondbacks received a strike! Strikes: 2
# Christian Walker of Arizona Diamondbacks got a ball! Balls: 1
# Christian Walker of Arizona Diamondbacks got out in the field!
# Runs scored in inning 6: Texas Rangers - 0, Arizona Diamondbacks - 0
# Outs after inning 6: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 6: Texas Rangers - 1, Arizona Diamondbacks - 1
#
# Inning 7:
#
# Marcus Semien's at-bat:
# Marcus Semien of Texas Rangers got a ball! Balls: 1
# Marcus Semien of Texas Rangers got a ball! Balls: 2
# Marcus Semien of Texas Rangers received a strike! Strikes: 1
# Marcus Semien of Texas Rangers got out in the field!
#
# Corey Seager's at-bat:
# Corey Seager of Texas Rangers received a strike! Strikes: 1
# Corey Seager of Texas Rangers got a ball! Balls: 1
# Corey Seager of Texas Rangers got a ball! Balls: 2
# Corey Seager of Texas Rangers got a hit! Players on base: 1
#
# Josh Jung's at-bat:
# Josh Jung of Texas Rangers got out in the field!
#
# Evan Carter's at-bat:
# Evan Carter of Texas Rangers got a ball! Balls: 1
# Evan Carter of Texas Rangers got a ball! Balls: 2
# Evan Carter of Texas Rangers got a ball! Balls: 3
# Evan Carter of Texas Rangers got a ball! Balls: 4
#
# Leody Taveras's at-bat:
# Leody Taveras of Texas Rangers got a ball! Balls: 1
# Leody Taveras of Texas Rangers got a ball! Balls: 2
# Leody Taveras of Texas Rangers got out in the field!
#
# Tommy Pham's at-bat:
# Tommy Pham of Arizona Diamondbacks got a hit! Players on base: 1
#
# Lourdes Gurriel Jr.'s at-bat:
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 1
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 2
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 3
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 4
#
# Alek Thomas's at-bat:
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 1
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 2
# Alek Thomas of Arizona Diamondbacks got a hit! Players on base: 2
#
# Evan Longoria's at-bat:
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 1
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 2
# Evan Longoria of Arizona Diamondbacks received a strike! Strikes: 1
# Evan Longoria of Arizona Diamondbacks received a strike! Strikes: 2
# Evan Longoria of Arizona Diamondbacks got a ball! Balls: 3
# Evan Longoria of Arizona Diamondbacks received a strike! Strikes: 3
# Evan Longoria of Arizona Diamondbacks struck out!
#
# Geraldo Perdomo's at-bat:
# Geraldo Perdomo of Arizona Diamondbacks received a strike! Strikes: 1
# Geraldo Perdomo of Arizona Diamondbacks received a strike! Strikes: 2
# Geraldo Perdomo of Arizona Diamondbacks got a hit! Players on base: 3
#
# Corbin Carrol's at-bat:
# Corbin Carrol of Arizona Diamondbacks got out in the field!
#
# Ketel Marte's at-bat:
# Ketel Marte of Arizona Diamondbacks got a ball! Balls: 1
# Ketel Marte of Arizona Diamondbacks got out in the field!
# Runs scored in inning 7: Texas Rangers - 0, Arizona Diamondbacks - 0
# Outs after inning 7: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 7: Texas Rangers - 1, Arizona Diamondbacks - 3
#
# Inning 8:
#
# Adolis García's at-bat:
# Adolis García of Texas Rangers got a ball! Balls: 1
# Adolis García of Texas Rangers got a ball! Balls: 2
# Adolis García of Texas Rangers got a ball! Balls: 3
# Adolis García of Texas Rangers received a strike! Strikes: 1
# Adolis García of Texas Rangers got a ball! Balls: 4
#
# Mitch Garver's at-bat:
# Mitch Garver of Texas Rangers got a ball! Balls: 1
# Mitch Garver of Texas Rangers got a ball! Balls: 2
# Mitch Garver of Texas Rangers got a ball! Balls: 3
# Mitch Garver of Texas Rangers got a ball! Balls: 4
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got out in the field!
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers received a strike! Strikes: 1
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 1
# Nathaniel Lowe of Texas Rangers got a ball! Balls: 2
# Nathaniel Lowe of Texas Rangers got out in the field!
#
# Marcus Semien's at-bat:
# Marcus Semien of Texas Rangers got a ball! Balls: 1
# Marcus Semien of Texas Rangers got a ball! Balls: 2
# Marcus Semien of Texas Rangers got a ball! Balls: 3
# Marcus Semien of Texas Rangers got a hit! Players on base: 1
#
# Corey Seager's at-bat:
# Corey Seager of Texas Rangers got a ball! Balls: 1
# Corey Seager of Texas Rangers got a hit! Players on base: 2
#
# Josh Jung's at-bat:
# Josh Jung of Texas Rangers got a ball! Balls: 1
# Josh Jung of Texas Rangers got a ball! Balls: 2
# Josh Jung of Texas Rangers received a strike! Strikes: 1
# Josh Jung of Texas Rangers got a hit! Players on base: 3
#
# Evan Carter's at-bat:
# Evan Carter of Texas Rangers got out in the field!
#
# Gabriel Moreno's at-bat:
# Gabriel Moreno of Arizona Diamondbacks got out in the field!
#
# Christian Walker's at-bat:
# Christian Walker of Arizona Diamondbacks got a ball! Balls: 1
# Christian Walker of Arizona Diamondbacks got out in the field!
#
# Tommy Pham's at-bat:
# Tommy Pham of Arizona Diamondbacks received a strike! Strikes: 1
# Tommy Pham of Arizona Diamondbacks received a strike! Strikes: 2
# Tommy Pham of Arizona Diamondbacks got a ball! Balls: 1
# Tommy Pham of Arizona Diamondbacks got out in the field!
# Runs scored in inning 8: Texas Rangers - 0, Arizona Diamondbacks - 0
# Outs after inning 8: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 8: Texas Rangers - 3, Arizona Diamondbacks - 0
#
# Inning 9:
#
# Leody Taveras's at-bat:
# Leody Taveras of Texas Rangers got a ball! Balls: 1
# Leody Taveras of Texas Rangers got a hit! Players on base: 1
#
# Adolis García's at-bat:
# Adolis García of Texas Rangers got a hit! Players on base: 2
#
# Mitch Garver's at-bat:
# Mitch Garver of Texas Rangers got a ball! Balls: 1
# Mitch Garver of Texas Rangers got a ball! Balls: 2
# Mitch Garver of Texas Rangers got a ball! Balls: 3
# Mitch Garver of Texas Rangers got out in the field!
#
# Jonah Heim's at-bat:
# Jonah Heim of Texas Rangers got a ball! Balls: 1
# Jonah Heim of Texas Rangers got a ball! Balls: 2
# Jonah Heim of Texas Rangers got a ball! Balls: 3
# Jonah Heim of Texas Rangers got out in the field!
#
# Nathaniel Lowe's at-bat:
# Nathaniel Lowe of Texas Rangers got out in the field!
#
# Lourdes Gurriel Jr.'s at-bat:
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 1
# Lourdes Gurriel Jr. of Arizona Diamondbacks got a ball! Balls: 2
# Lourdes Gurriel Jr. of Arizona Diamondbacks got out in the field!
#
# Alek Thomas's at-bat:
# Alek Thomas of Arizona Diamondbacks got a ball! Balls: 1
# Alek Thomas of Arizona Diamondbacks received a strike! Strikes: 1
# Alek Thomas of Arizona Diamondbacks got out in the field!
#
# Evan Longoria's at-bat:
# Evan Longoria of Arizona Diamondbacks got a hit! Players on base: 1
#
# Geraldo Perdomo's at-bat:
# Geraldo Perdomo of Arizona Diamondbacks got a ball! Balls: 1
# Geraldo Perdomo of Arizona Diamondbacks got out in the field!
# Runs scored in inning 9: Texas Rangers - 0, Arizona Diamondbacks - 0
# Outs after inning 9: Texas Rangers - 3, Arizona Diamondbacks - 3
# On base after inning 9: Texas Rangers - 2, Arizona Diamondbacks - 1
#
# Final Score: Texas Rangers - 2, Arizona Diamondbacks - 5
# Arizona Diamondbacks wins!
